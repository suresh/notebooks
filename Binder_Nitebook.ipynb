# %%
# !pip install pandas matplotlib pandas_datareader
# Out:
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/7e/ab/ea76361f9d3e732e114adcd801d2820d5319c23d0ac5482fa3b412db217e/pandas-0.25.1-cp37-cp37m-manylinux1_x86_64.whl (10.4MB)
#      |████████████████████████████████| 10.4MB 3.4MB/s eta 0:00:01
# Collecting matplotlib
#   Downloading https://files.pythonhosted.org/packages/19/7a/60bd79c5d79559150f8bba866dd7d434f0a170312e4d15e8aefa5faba294/matplotlib-3.1.1-cp37-cp37m-manylinux1_x86_64.whl (13.1MB)
#      |████████████████████████████████| 13.1MB 30.3MB/s eta 0:00:01
# Collecting pandas_datareader
#   Downloading https://files.pythonhosted.org/packages/d1/db/c6c72242179251ed9ead7af852296ae9558b1d0cfd972eef6c3398b131d1/pandas_datareader-0.7.4-py2.py3-none-any.whl (113kB)
#      |████████████████████████████████| 122kB 48.0MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.6.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2.8.0)
# Collecting pytz>=2017.2 (from pandas)
#   Downloading https://files.pythonhosted.org/packages/87/76/46d697698a143e05f77bec5a526bf4e56a0be61d63425b68f4ba553b51f2/pytz-2019.2-py2.py3-none-any.whl (508kB)
#      |████████████████████████████████| 512kB 57.4MB/s eta 0:00:01
# Collecting numpy>=1.13.3 (from pandas)
#   Downloading https://files.pythonhosted.org/packages/25/eb/4ecf6b13897391cb07a4231e9d9c671b55dfbbf6f4a514a1a0c594f2d8d9/numpy-1.17.1-cp37-cp37m-manylinux1_x86_64.whl (20.3MB)
#      |████████████████████████████████| 20.3MB 37.7MB/s eta 0:00:01
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/11/fa/0160cd525c62d7abd076a070ff02b2b94de589f1a9789774f17d7c54058e/pyparsing-2.4.2-py2.py3-none-any.whl (65kB)
#      |████████████████████████████████| 71kB 33.6MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/93/f8/518fb0bb89860eea6ff1b96483fbd9236d5ee991485d0f3eceff1770f654/kiwisolver-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (90kB)
#      |████████████████████████████████| 92kB 40.5MB/s eta 0:00:01
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.3.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas_datareader) (2.22.0)
# Collecting wrapt (from pandas_datareader)
#   Downloading https://files.pythonhosted.org/packages/23/84/323c2415280bc4fc880ac5050dddfb3c8062c2552b34c2e512eb4aa68f79/wrapt-1.11.2.tar.gz
# Collecting lxml (from pandas_datareader)
#   Downloading https://files.pythonhosted.org/packages/e7/a8/40115c84414c017e1a293f331709eb7534303d3ccd11ef805ac09b1481e7/lxml-4.4.1-cp37-cp37m-manylinux1_x86_64.whl (5.7MB)
#      |████████████████████████████████| 5.8MB 33.0MB/s eta 0:00:01     |████████████████████▎           | 3.6MB 33.0MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (41.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (1.25.3)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (3.0.4)
# Building wheels for collected packages: wrapt
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.11.2-cp37-cp37m-linux_x86_64.whl size=70724 sha256=4c2482f45babf7f30769fbbd972eec5bdd32d2468b423457fded457e1f01c7c9
#   Stored in directory: /home/jovyan/.cache/pip/wheels/d7/de/2e/efa132238792efb6459a96e85916ef8597fcb3d2ae51590dfd
# Successfully built wrapt
# Installing collected packages: pytz, numpy, pandas, pyparsing, kiwisolver, cycler, matplotlib, wrapt, lxml, pandas-datareader
# Successfully installed cycler-0.10.0 kiwisolver-1.1.0 lxml-4.4.1 matplotlib-3.1.1 numpy-1.17.1 pandas-0.25.1 pandas-datareader-0.7.4 pyparsing-2.4.2 pytz-2019.2 wrapt-1.11.2

# %%
import pandas_datareader as data
# %matplotlib inline

# %%
aapl = data.DataReader('AAPL', 'yahoo', '2018-01-01', '2019-08-31')

# %%
aapl.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2018-01-02  172.300003  169.259995  170.160004  172.259995  25555900.0
# 2018-01-03  174.550003  171.960007  172.529999  172.229996  29517900.0
# 2018-01-04  173.470001  172.080002  172.539993  173.029999  22434600.0
# 2018-01-05  175.369995  173.050003  173.440002  175.000000  23660000.0
# 2018-01-08  175.610001  173.929993  174.350006  174.350006  20567800.0
#
#              Adj Close
# Date
# 2018-01-02  167.701889
# 2018-01-03  167.672668
# 2018-01-04  168.451508
# 2018-01-05  170.369385
# 2018-01-08  169.736588

# %%
aapl['Close'].plot(figsize=(12,9))
